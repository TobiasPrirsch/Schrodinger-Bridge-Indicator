# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %%javascript
# //IPython.OutputArea.auto_scroll_threshold = 9999;   //设置输出>9999时才出现滑动窗口
# IPython.OutputArea.prototype._should_scroll = function(){return false}  // 设置不出现滑动窗口 true, auto, false

# %%
steady = np.load('homoclinc_point.npy')
cycle = np.load('homoclinc_cycle.npy')
# verymild = np.load('veryx.npy')
steady.shape, cycle.shape
# Out:
# ((2,), (585, 2))

# %%
plt.figure(figsize=(8,6))
plt.scatter(steady[0], steady[1], alpha=0.5, label='steady')
plt.scatter(cycle[:,0], cycle[:,1], alpha=0.5, label='cycle')
# plt.scatter(verymild[:,0], verymild[:,1], alpha=0.5, label='verymild')
plt.grid(1)
plt.legend()
plt.show()

# %%
plt.scatter(cycle[:,0], cycle[:,1], alpha=0.5, label='cycle')

# %%
loss_list = np.load('loss.npy')
plt.plot(loss_list[700:])

# %%
steady
# Out:
# array([-3.57110594e+01,  4.13538942e-03])

# %%
zf = np.load('zf.npy')
zf = np.mean(zf, axis=(1,-1))
zf.shape
# Out:
# (2000, 100)

# %%
ee = 0

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.plot((zf[ee, :])**2, label=f'{ee} step')
plt.legend()
plt.subplot(2,1,2)
inte = np.cumsum((zf[ee, :])**2)
plt.plot(inte, label=f'{ee} step')
plt.legend()
ee += 50

# %%
plt.figure(figsize=(8,6))
inte = np.cumsum((zf[ee, :])**2)
plt.plot(inte, label=f'{ee} step')
plt.legend()
ee += 50

# %%
plt.figure(figsize=(8,6))
loss_list = np.load('loss.npy')
plt.plot(loss_list[20:], label='Loss')
plt.legend(fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig('morris2_loss.png', bbox_inches='tight', dpi=150)
plt.show()

# %%
loss = np.load('loss.npy')
plt.plot(loss[20:])

# %%
episode = 1500
tra = np.load(f'train_itf{episode}.npy')
length = tra.shape[1] // 5
plt.figure(figsize=(20,30))
plt.subplot(6, 2, 1)
# plt.scatter(cycle[:,0], cycle[:,1], s=5)
# plt.figure(figsize=(4,3))
plt.scatter(tra[:, 0, 0], tra[:, 0, 1], label=f'1 step')
# plt.scatter(steady[0], steady[1], c='r', s=20)
plt.scatter(cycle[:,0], cycle[:,1], alpha=0.5, label='cycle')
# plt.xlim(-60,50)
# plt.ylim(0, 0.6)
plt.legend()
# plt.show()

for i in range(5):
    num = (i+1)*length-1
    plt.subplot(6, 2, i*2+3)
#     plt.figure(figsize=(4,3))
#     plt.scatter(cycle[:,0], cycle[:,1], s=5)
    plt.scatter(tra[:, num, 0], tra[:, num, 1], label=f'{(i+1)*length} step')
#     plt.scatter(steady[0], steady[1], c='r', s=20)
    plt.scatter(cycle[:,0], cycle[:,1], alpha=0.5, label='cycle')
#     plt.xlim(-60,50)
#     plt.ylim(0, 0.6)
    plt.legend()
#     plt.show()
    
tra = np.load(f'train_itbb{episode}.npy')
plt.subplot(6, 2, 2)
# plt.figure(figsize=(4,3))
# plt.scatter(cycle[:,0], cycle[:,1], s=5)
plt.scatter(tra[:, 0, 0], tra[:, 0, 1], label=f'1 step')
plt.scatter(cycle[:,0], cycle[:,1], alpha=0.5, label='cycle')
# plt.xlim(-60,50)
# plt.ylim(0, 0.6)
plt.legend()
# plt.show()

for i in range(5):
    num = (i+1)*length-1
#     num = 100 - num
    plt.subplot(6, 2, i*2+4)
#     plt.scatter(cycle[:,0], cycle[:,1], s=5)
#     plt.figure(figsize=(4,3))
    plt.scatter(tra[:, num, 0], tra[:, num, 1], label=f'{(i+1)*length} step')
    plt.scatter(cycle[:,0], cycle[:,1], alpha=0.5, label='cycle')
#     plt.xlim(-60,50)
#     plt.ylim(0, 0.6)
    plt.legend()
plt.show()

# %%
episode = 700
tra = np.load(f'train_itf{episode}.npy')
length = tra.shape[1] // 5
plt.figure(figsize=(20,30))
plt.subplot(6, 2, 1)
plt.scatter(cycle[:,0], cycle[:,1], s=5)
# plt.figure(figsize=(4,3))
plt.scatter(tra[:, 0, 0], tra[:, 0, 1], label=f'1 step')
plt.xlim(-60,50)
plt.ylim(0, 0.6)
plt.legend()
# plt.show()

for i in range(5):
    num = (i+1)*length-1
    plt.subplot(6, 2, i*2+3)
#     plt.figure(figsize=(4,3))
    plt.scatter(cycle[:,0], cycle[:,1], s=5)
    plt.scatter(tra[:, num, 0], tra[:, num, 1], label=f'{(i+1)*length} step')
    plt.xlim(-60,50)
    plt.ylim(0, 0.6)
    plt.legend()
#     plt.show()
    
tra = np.load(f'train_itb1{episode}.npy')
plt.subplot(6, 2, 2)
# plt.figure(figsize=(4,3))
plt.scatter(cycle[:,0], cycle[:,1], s=5)
plt.scatter(tra[:, 0, 0], tra[:, 0, 1], label=f'1 step')
plt.xlim(-60,50)
plt.ylim(0, 0.6)
plt.legend()
# plt.show()

for i in range(5):
    num = (i+1)*length-1
#     num = 100 - num
    plt.subplot(6, 2, i*2+4)
    plt.scatter(cycle[:,0], cycle[:,1], s=5)
#     plt.figure(figsize=(4,3))
    plt.scatter(tra[:, num, 0], tra[:, num, 1], label=f'{(i+1)*length} step')
    plt.xlim(-60,50)
    plt.ylim(0, 0.6)
    plt.legend()
plt.show()

# %%
episode = 900
tra = np.load(f'train_itf{episode}.npy')
length = tra.shape[1] // 5
plt.figure(figsize=(20,30))
plt.subplot(6, 2, 1)
plt.scatter(cycle[:,0], cycle[:,1], s=5)
# plt.figure(figsize=(4,3))
plt.scatter(tra[:, 0, 0], tra[:, 0, 1], label=f'1 step')
plt.xlim(-60,50)
plt.ylim(0, 0.6)
plt.legend()
# plt.show()

for i in range(5):
    num = (i+1)*length-1
    plt.subplot(6, 2, i*2+3)
#     plt.figure(figsize=(4,3))
    plt.scatter(cycle[:,0], cycle[:,1], s=5)
    plt.scatter(tra[:, num, 0], tra[:, num, 1], label=f'{(i+1)*length} step')
    
    plt.xlim(-60,50)
    plt.ylim(0, 0.6)
    plt.legend()
#     plt.show()
    
tra = np.load(f'train_itb1{episode}.npy')
plt.subplot(6, 2, 2)
# plt.figure(figsize=(4,3))
plt.scatter(cycle[:,0], cycle[:,1], s=5)
plt.scatter(tra[:, 0, 0], tra[:, 0, 1], label=f'1 step')
plt.xlim(-60,50)
plt.ylim(0, 0.6)
plt.legend()
# plt.show()

for i in range(5):
    num = (i+1)*length-1
#     num = 100 - num
    plt.subplot(6, 2, i*2+4)
#     plt.figure(figsize=(4,3))
    plt.scatter(cycle[:,0], cycle[:,1], s=5)
    plt.scatter(tra[:, num, 0], tra[:, num, 1], label=f'{(i+1)*length} step')
    plt.xlim(-60,50)
    plt.ylim(0, 0.6)
    plt.legend()
plt.show()

# %%
tra = np.load('train_itb300.npy')
print(tra.shape)
plt.scatter(non[:,0], non[:,1], label='target')
# plt.xlim(-50,65)
# plt.ylim(-30,25)
plt.legend()
plt.show()
plt.scatter(tra[:, -1, 0], tra[:, -1, 1], label=f'1 step')
# plt.xlim(-50,65)
# plt.ylim(-30,25)
plt.legend()
plt.show()
